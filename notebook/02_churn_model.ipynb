# %%
import sqlite3
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

# %%
query: str = """
SELECT 
c.customer_unique_id,
c.customer_city, 
c.customer_state,
COUNT(DISTINCT o.order_id) AS total_orders,
SUM(oi.price) AS total_spent,
AVG(oi.price) AS average_spent,
 AVG(
        julianday(o.order_delivered_customer_date)
        - julianday(o.order_estimated_delivery_date)
    ) AS avg_delivery_lateness,
AVG(ore.review_score) AS avg_review_score,
COUNT(DISTINCT p.product_category_name) AS num_categories
FROM customers AS c
JOIN orders AS o 
ON c.customer_id = o.customer_id
JOIN "order reviews" AS ore 
ON o.order_id = ore.order_id
JOIN "order items" AS oi
ON o.order_id = oi.order_id
JOIN products AS p
ON oi.product_id = p.product_id
GROUP BY c.customer_unique_id, c.customer_city, c.customer_state
            """
conn: sqlite3.Connection = sqlite3.connect("../database/olist.db")
df: pd.DataFrame = pd.read_sql(query, conn)
conn.close()

df
# Out:
#                      customer_unique_id       customer_city customer_state  \
# 0      0000366f3b9a7992bf8c76cfdf3221e2             cajamar             SP
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f              osasco             SP
# 2      0000f46a3911fa3c0805444483337064            sao jose             SC
# 3      0000f6ccb0745a6a4b88665a16c9f078               belem             PA
# 4      0004aac84e0df4da2b147fca70cf8255            sorocaba             SP
# ...                                 ...                 ...            ...
# 94833  fffcf5a5ff07b0908bd4e2dbc735a684             sanharo             PE
# 94834  fffea47cd6d3cc0a88bd621562a9d061    feira de santana             BA
# 94835  ffff371b4d645b6ecea244b27531430a               sinop             MT
# 94836  ffff5962728ec6157033ef9805bacc48  bom jesus do norte             ES
# 94837  ffffd2657e2aad2907e67c3e9daecbeb         campo largo             PR
#
#        total_orders  total_spent  average_spent  avg_delivery_lateness  \
# 0                 1       129.90         129.90              -4.132905
# 1                 1        18.90          18.90              -4.248125
# 2                 1        69.00          69.00              -1.389734
# 3                 1        25.99          25.99             -11.108970
# 4                 1       180.00         180.00              -7.035463
# ...             ...          ...            ...                    ...
# 94833             1      1570.00         785.00             -26.609722
# 94834             1        64.89          64.89              -2.063657
# 94835             1        89.90          89.90             -29.468704
# 94836             1       115.00         115.00             -13.503866
# 94837             1        56.99          56.99             -15.601528
#
#        avg_review_score  num_categories
# 0                   5.0               1
# 1                   4.0               1
# 2                   3.0               1
# 3                   4.0               1
# 4                   5.0               1
# ...                 ...             ...
# 94833               5.0               1
# 94834               4.0               1
# 94835               5.0               1
# 94836               5.0               1
# 94837               5.0               1
#
# [94838 rows x 9 columns]

# %%
#order payments -> payments
